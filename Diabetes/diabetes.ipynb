# %%
import pandas as pd
import numpy as np
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
df=pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.isna()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# 1                       False  False    False
# 2                       False  False    False
# 3                       False  False    False
# 4                       False  False    False
# ..                        ...    ...      ...
# 763                     False  False    False
# 764                     False  False    False
# 765                     False  False    False
# 766                     False  False    False
# 767                     False  False    False
#
# [768 rows x 9 columns]

# %%
df.SkinThickness.value_counts()
# Out:
# SkinThickness
# 0     227
# 32     31
# 30     27
# 27     23
# 23     22
# 18     20
# 33     20
# 28     20
# 31     19
# 39     18
# 19     18
# 29     17
# 25     16
# 40     16
# 22     16
# 37     16
# 26     16
# 41     15
# 35     15
# 36     14
# 15     14
# 17     14
# 20     13
# 24     12
# 42     11
# 13     11
# 21     10
# 46      8
# 34      8
# 12      7
# 38      7
# 16      6
# 11      6
# 45      6
# 14      6
# 43      6
# 44      5
# 10      5
# 47      4
# 48      4
# 49      3
# 50      3
# 54      2
# 8       2
# 52      2
# 7       2
# 60      1
# 51      1
# 56      1
# 63      1
# 99      1
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.Outcome.value_counts()
# Out:
# Outcome
# 0    500
# 1    268
# Name: count, dtype: int64

# %%
df.Insulin.value_counts()
# Out:
# Insulin
# 0      374
# 105     11
# 130      9
# 140      9
# 120      8
#       ...
# 178      1
# 127      1
# 510      1
# 16       1
# 112      1
# Name: count, Length: 186, dtype: int64

# %%
x=df.drop(["Outcome"],axis='columns')
y=df.Outcome

# %%
scaler=StandardScaler()
X=scaler.fit_transform(x)
X[:10]
# Out:
# array([[ 0.63994726,  0.84832379,  0.14964075,  0.90726993, -0.69289057,
#          0.20401277,  0.46849198,  1.4259954 ],
#        [-0.84488505, -1.12339636, -0.16054575,  0.53090156, -0.69289057,
#         -0.68442195, -0.36506078, -0.19067191],
#        [ 1.23388019,  1.94372388, -0.26394125, -1.28821221, -0.69289057,
#         -1.10325546,  0.60439732, -0.10558415],
#        [-0.84488505, -0.99820778, -0.16054575,  0.15453319,  0.12330164,
#         -0.49404308, -0.92076261, -1.04154944],
#        [-1.14185152,  0.5040552 , -1.50468724,  0.90726993,  0.76583594,
#          1.4097456 ,  5.4849091 , -0.0204964 ],
#        [ 0.3429808 , -0.15318486,  0.25303625, -1.28821221, -0.69289057,
#         -0.81134119, -0.81807858, -0.27575966],
#        [-0.25095213, -1.34247638, -0.98770975,  0.71908574,  0.07120427,
#         -0.12597727, -0.676133  , -0.61611067],
#        [ 1.82781311, -0.184482  , -3.57259724, -1.28821221, -0.69289057,
#          0.41977549, -1.02042653, -0.36084741],
#        [-0.54791859,  2.38188392,  0.04624525,  1.53455054,  4.02192191,
#         -0.18943689, -0.94794368,  1.68125866],
#        [ 1.23388019,  0.12848945,  1.39038675, -1.28821221, -0.69289057,
#         -4.06047387, -0.7244549 ,  1.76634642]])

# %%
x_train,x_test,y_train,y_test=train_test_split(X,y,train_size=0.8)
x_train[:10]
# Out:
# array([[-0.54791859,  0.56664949,  0.304734  , -1.28821221, -0.69289057,
#         -0.81134119, -0.92076261, -0.36084741],
#        [ 2.12477957,  0.19108374,  1.90736425, -1.28821221, -0.69289057,
#          0.8893767 , -0.85129988,  1.51108316],
#        [ 0.04601433,  1.16129525,  0.45982725, -1.28821221, -0.69289057,
#          0.1151693 ,  1.00003286, -0.19067191],
#        [-0.84488505, -0.27837344,  0.14964075,  0.59362962,  0.83529911,
#          0.30554817,  0.16950023, -0.70119842],
#        [-0.54791859, -0.27837344,  0.45982725,  1.84819084,  0.52271486,
#          0.94014439, -0.89660166, -0.78628618],
#        [-0.84488505, -0.24707629, -0.26394125,  0.90726993, -0.69289057,
#          0.20401277,  0.21480201, -1.04154944],
#        [-1.14185152, -0.59134489,  0.304734  ,  0.15453319, -0.69289057,
#         -4.06047387,  0.30238545, -1.04154944],
#        [-0.84488505, -0.46615631,  0.35643175, -1.28821221, -0.69289057,
#          0.69899783, -0.83015905, -0.61611067],
#        [-0.54791859, -0.30967058, -0.47073225, -1.28821221, -0.69289057,
#         -0.73518964, -0.38922173, -0.87137393],
#        [-0.25095213, -1.15469351, -0.05715025,  0.59362962,  0.2274964 ,
#         -0.01174995,  0.3597677 , -0.70119842]])

# %%
model=svm.SVC(kernel='linear')
model.fit(x_train,y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred=model.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8311688311688312

# %%
df1=pd.DataFrame({'True val':y_pred,'Pred val':y_test})
df1.head()
# Out:
#      True val  Pred val
# 296         0         1
# 654         0         0
# 639         0         0
# 421         0         0
# 716         1         1

# %%
data=np.array([5,166,72,19,175,25.8,0.587,51])
data_shaped=scaler.transform([data])
if model.predict([data])==1:
    print("Positive DIabetes")
else:
    print("Negative Diabetes")
# Out:
# Positive DIabetes
# c:\WAHTEVER ELSE\GEEK STUFF\python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
data_shaped[0][2]
# Out:
# np.float64(0.149640752628208)
